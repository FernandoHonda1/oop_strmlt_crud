# %%
from connect import babies_params, connect
import page
import pandas as pd

# %%
con = connect(babies_params)
pg = page.Page(con)

# %%
data = pg.base_data['all']

# %%
data.loc[data['classe'].isin(['a','b'])]
# Out:
#       id           nome  dia  mes   ano classe  nota1  nota2  nota3
# 1      1            Ryo   20    7  1936      a     33     41     42
# 2      2          Kasha   25   11  1988      a     88     36     48
# 4      4  Kayleb-Arthur   25    7  1956      b      2     42     24
# 7      7        Ryleigh   20    1  2010      a     58     33      7
# 13    13       Shehryar    3    2  1940      a     80     54      8
# ..   ...            ...  ...  ...   ...    ...    ...    ...    ...
# 493  493         Elyssa    9    3  1933      b      5     86     40
# 494  494           Bony   24    9  1980      b     84     94     25
# 495  495         Sunena   10   10  1995      b     35     44     50
# 496  496            Wan   19    1  1916      a     15     28     62
# 499  499           Dick   11    2  1995      b     18     20     21
#
# [225 rows x 9 columns]

# %%
data.loc[(data['ano'] >= 1990) & (data['ano'] <= 2000)]
# Out:
#       id          nome  dia  mes   ano classe  nota1  nota2  nota3
# 10    10      Ambroise   25    7  1990      d     63     35     38
# 23    23         Donal    6    9  1990      a     52      6     91
# 32    32        Caradh   19    4  1996      e      3     18     88
# 42    42        Amelia   10    7  2000      a     82     83     13
# 50    50          Chak   23    5  1990      d    100     13     90
# 62    62         Edwin    8    7  1996      d     53     84     15
# 63    63        Bariah   26    7  2000      b     42     34      6
# 106  106          Ross    2    6  1991      b     56     17     20
# 113  113       Harjeev   31    6  1993      a     90     41     82
# 118  118         Ceryn    5    9  1993      c      9      8     82
# 135  135    Subramanya   26    7  1998      b     32     44     66
# 146  146         Tanis   10   12  1990      c     13     39     86
# 152  152         Beinn   15    5  1991      d     74     31     90
# ...
